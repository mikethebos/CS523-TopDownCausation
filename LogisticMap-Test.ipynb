# %%
import numpy as np
import matplotlib.pyplot as plt
from LogisticGrowthModel import *

# %%
def instRepFittnessFun(carryCap=100, maxRepFitt=4):
    return lambda pops: maxRepFitt/(1+np.exp((np.sum(pops) - carryCap)/(carryCap/maxRepFitt)))

# %%
N_transient  = 1000
N_steadyState= 3000 
N = 500 # Number of coupled logistic growth maps
r = np.random.uniform(low=0,high=4.0, size=(N,))
K = np.ones(shape=(N,))*100
statGrowthModels = generateGrowthModels(r,K)
dynGrowthModels  = generateGrowthModels(instRepFittnessFun(100,,K)

# %%
X = np.zeros(shape=(N,N_steadyState))
X[:,0]=1.0
for n in range(N_transient):
    X[:,0]= globalLogisticGrowth(X[:,0],growthModels,0)
for i in range(N_steadyState-1):
    X[:,i+1]=globalLogisticGrowth(X[:,i],growthModels,0)

# %%
for inx in range(len(r)):
    plt.plot(np.ones(X[inx,:].shape)*r[inx],X[inx,:],'o',markerfacecolor='none', markeredgecolor='k', alpha=0.01, 
             markersize=1)
plt.xlabel('Reproduction Rate', fontsize=12);
plt.ylabel('Population',fontsize=12);

# %%
Rmax = 4; carryCap=100
totalpop =np.linspace(0,2*carryCap,100)
plt.plot(totalpop,[instRepFittnessFun(carryCap, Rmax)(p) for p in totalpop])
plt.ylabel("Reproductive Fitteness");
plt.xlabel("Total Population");

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-23c0112f1134> in <module>
#       2 Xdynamic = np.zeros(shape=(5,100))
#       3 Xdynamic[:,0] = np.ones(shape=(5,))
# ----> 4 growthModels = generateGrowthModels(carryCaps=K, repFitCoeffs=instRepFittnessFun(100,3))
#       5 for t in range(100-1):
#       6     Xdynamic[:,t+1] = growthModels(Xdynamic[:,t])
#
# ~\Documents\GitHub\CS523-TopDownCausation\LogisticGrowthModel.py in generateGrowthModels(repFitCoeffs, carryCaps)
#      91         return lambda pops:np.array([localLogisticGrowth(p,repFitCoeffs(pops),carryCaps(pops)) for p in pops])
#      92     if isinstance(repFitCoeffs,(type(lambda:1),)):
# ---> 93         r = repFitCoeffs(pops)
#      94         return lambda pops:np.array([localLogisticGrowth(p,r,k) for p,k in zip(pops,carryCaps)])
#      95     if isinstance(carryCaps,(type(lambda:1),)):
#
# ...
